# %%
import pandas as pd
from itertools import product

# %%
all_results = []
for i in range(7):

# initializing K
    k = i + 1
    # using product() to get Combinations and repeat to get elements
    combos = list(product(range(1, 7), repeat = k))
    
    # parse the combinations for outcomes
    dice = k
    crit = 0
    success = 0
    mixed = 0
    fail = 0
    total = 6**k
    for combo in combos:
        if combo.count(6) >= 2:
            crit += 1
        elif max(combo) == 6:
            success += 1
        elif max(combo) >= 4:
            mixed += 1
        else:
            fail += 1
    percent_crit = crit / total * 100
    percent_success = success / total * 100
    percent_mixed = mixed / total * 100
    percent_fail = fail / total * 100
    results = [dice, percent_fail, percent_mixed, percent_success, percent_crit]
    all_results.append(results)

# %%
# Create a dataframe with the action roll probabilities
action_df = pd.DataFrame(all_results, columns=['Dice', '% Failure', '% Mixed', '% Success', '% Critical'])
# format the percentagesin dataframe
action_df['% Failure'] = action_df['% Failure'].map("{:.1f}".format)
action_df['% Mixed'] = action_df['% Mixed'].map("{:.1f}".format)
action_df['% Success'] = action_df['% Success'].map("{:.1f}".format)
action_df['% Critical'] = action_df['% Critical'].map("{:.1f}".format)

# %%
action_df
# Out:
#    Dice % Failure % Mixed % Success % Critical
# 0     1      50.0    33.3      16.7        0.0
# 1     2      25.0    44.4      27.8        2.8
# 2     3      12.5    45.4      34.7        7.4
# 3     4       6.2    42.0      38.6       13.2
# 4     5       3.1    37.1      40.2       19.6
# 5     6       1.6    31.9      40.2       26.3
# 6     7       0.8    27.1      39.1       33.0
